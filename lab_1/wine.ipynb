# %%
import pandas as pd

df = pd.read_csv("winequalityN.csv")

# %%
df

# %%
#rootmean square error
#coz can have +ve/-ve so do power or 2 first then square root it

#mean absolute error
#do rounding first then do mean

#result rm/ma- mean the predict data have that much different
#if the result is like 0.1.. means the predicted data result it accurate
#coz the different error only 0.1

#overfitting- a data is too big  compare to another data.
#it can effect or cancel the small data when predict
#y^ = total wi+xi+ b 
#the different loss = i/n total y-y^
#can also make power of 2 to get balance data if it too big

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import root_mean_squared_error, mean_absolute_error


#alpha= 강도

# %%
linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)
