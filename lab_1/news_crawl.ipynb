# %%
import requests
#get method have query/keyword after ?
#post method only link
#https://search.naver.com/search.naver?ssc=tab.news.all&query=%EA%B0%95%EC%9B%90%EB%8C%80&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds=2025.10.01&de=2025.10.21&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom20251001to20251021&is_sug_officeid=0&office_category=0&service_area=0

# %%
import requests

url="https://s.search.naver.com/p/newssearch/3/api/tab/more?nso=so%3Ar%2Cp%3Afrom20251001to20251021%2Ca%3Aall&query=%EA%B0%95%EC%9B%90%EB%8C%80&sort=0&spq=0&ssc=tab.news.all&start=1"

#query, sort, nso, ssc, start- parameter that need in the url for naver link

# %%
response = requests.get(url)

# %%
response_data = response.json()
url = response_data["url"]

# %%
url
# Out:
# 'https://s.search.naver.com/p/newssearch/3/api/tab/more?abt=null&cluster_rank=25&de=&ds=&eid=&field=0&force_original=&is_dts=0&is_sug_officeid=0&mynews=0&news_office_checked=&nlu_query=&nqx_theme=&nso=so%3Ar%2Cp%3Afrom20251001to20251021%2Ca%3Aall&nx_and_query=&nx_search_hlquery=&nx_search_query=&nx_sub_query=&office_category=&office_section_code=0&office_type=0&pd=3&photo=0&query=%EA%B0%95%EC%9B%90%EB%8C%80&query_original=&rev=0&service_area=&sm=tab_smr&sort=0&spq=0&ssc=tab.news.all&start=11'

# %%
script =response_data["collection"][0]["script"]

# %%
script
# Out:
# '<script>\n(function () {\n\n  var startApplication = function () {\n    var require = window.require.config({\n      "context": "fender_renderer_f19953e85ece228637bd"\n    });\n    require(["https://ssl.pstatic.net/sstatic/fe/fender/client/f19953e85ece228637bd/index.js"], function (entry) {\n      entry.bootstrap(document.getElementById("fdr-8b9eef9610964119ad5adac62f46ff44"), {"appElementAttrs":{"className":"_slog_visible","data-slog-container":"nws"},"meta":{"area":"nws","query":"강원대","ssc":"tab.news.all","ssuid":"news","ssuidExtra":"fender_renderer-news","token":"basic"},"refs":{"blockId":"news/prs_template_v2_news_tab_desk.ts"},"rootElementAttrs":{"className":"api_subject_bx"},"body":{"props":{"children":[{"props":{"color":"g90","size":"sm"},"templateId":"sdsHorzDivider"},{"props":{"children":[{"props":{"clickLog":{"content":{"element":".body","g":"5376.0000204552","i":"88155e58_000000000000000000204552","r":1,"source":"*b"},"image":{"element":".img","g":"5376.0000204552","i":"8
# ...

# %%
import re

script_source = response_data["collection"][0]["script"]
news_url = re.findall(r"\"contentHref\":\"(.*?)\"", script_source) #take only shortest pattern when put ?.
# Out:
# ['http://www.bosa.co.kr/news/articleView.html?idxno=2260339',
#  'https://news.kbs.co.kr/news/pc/view/view.do?ncd=8387020&ref=A',
#  'https://www.kwnews.co.kr/page/view/2025102016002837012',
#  'https://www.kado.net/news/articleView.html?idxno=2011270',
#  'http://www.veritas-a.com/news/articleView.html?idxno=577636',
#  'https://www.yna.co.kr/view/AKR20251020061900062?input=1195m',
#  'https://www.g1tv.co.kr/news?mid=1_207_6&newsid=334723',
#  'https://www.kwnews.co.kr/page/view/2025102018164921134',
#  'https://www.kado.net/news/articleView.html?idxno=2011493',
#  'http://www.veritas-a.com/news/articleView.html?idxno=577432']

# %%
from trafilatura import fetch_url, extract
import json

news_data =[]

for news_urls in news_url:
    download = fetch_url(news_url[0])
    news_content = json.loads(
        extract(download, output_format="json", with_metadata=True)
    )

# %%
date_range = ["2025.08.01","2025.08.02",...,"2025.10.31"]

for date in date_range:
    next_url = url.format(date)

    while next_url != "": #till last url
        response = requests.get(url)

        output = response.json()
        next_url= output["url"]
        script = output["collection"][0]["script"]

        news_url

        for url in news_url:
            #use trafilala to take context of articlee
            news_data.append(news_one)

# %%
from pandas import date_range

date_range("20251001", "20251021", freq="D")[0].strftime("%y%m%d")
# Out:
# '251001'
